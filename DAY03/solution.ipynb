# %% [markdown]
# ### 1

# %%
def square_cube():
    num = int(input("Enter the number you want to calculate square and cube for"))
    print(f"square of the number is {num*num}")
    print(f"cube of the number is {num*num*num}")

square_cube()
# Out:
# square of the number is 9
# cube of the number is 27

# %% [markdown]
# ### 2

# %%
def area():
    radius,base,height = map(int, input("Enter radius, base and height sperated by commas").split(','))
    print(f"Area of circle is : {(22/7)*radius*radius}")
    print(f"Area of Triangle is: {0.5*base*height}")
area()
# Out:
# Area of circle is : 78.57142857142857
# Area of Triangle is: 20.0

# %% [markdown]
# ### 3

# %%
def remainder():
    numenator,denomnator =map(int,input("enter numenator and denomenator seperated b /").split('/'))
    print(f"quotient = {(numenator//denomnator)}")
    print(f"remainder = {numenator%denomnator}")
remainder()
# Out:
# quotient = 7
# remainder = 1
