# %%
for i in reversed(range(5)):
    print("*"*i)
# Out:
# ****
# ***
# **
# *

# %%
for i in range(1,6):
    print(" "*(5-i) + "*"+2*(i-1)*"*"+" "*(5-i))
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
for i in reversed(range(1,6)):
    print(" "*(5-i) + "*"+2*(i-1)*"*"+" "*(5-i))
# Out:
# *********
#  *******
#   *****
#    ***
#     *
